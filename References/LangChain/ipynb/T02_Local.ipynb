# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/LLM/blob/main/References/LangChain/ipynb/T02_Local.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import warnings
warnings.filterwarnings("ignore")
from transformers import AutoModelForCausalLM, AutoTokenizer
import time

model_name = "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"
local_path = "./models"
os.makedirs(local_path, exist_ok=True)

start_time = time.time()
model = AutoModelForCausalLM.from_pretrained(
    pretrained_model_name_or_path=model_name)
model.save_pretrained(save_directory=local_path)
tokenizer = AutoTokenizer.from_pretrained(
    pretrained_model_name_or_path=model_name)
tokenizer.save_pretrained(save_directory=local_path)
end_time = time.time() - start_time

print("Time taken: %.2f"%(end_time))
# Out:
# Time taken: 389.40

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from langchain_huggingface import HuggingFacePipeline

model = AutoModelForCausalLM.from_pretrained(
    pretrained_model_name_or_path=local_path)
tokenizer = AutoTokenizer.from_pretrained(
    pretrained_model_name_or_path=local_path)

hf_pipeline = pipeline(model=model, tokenizer=tokenizer,
    task="text-generation")
llm = HuggingFacePipeline(pipeline=hf_pipeline)
# Out:
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:00<00:00,  5.46it/s]
# The tokenizer you are loading from './models' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Device set to use cpu

# %%
from langchain_core.prompts import PromptTemplate
import time

template = """
Question: {question}
"""
prompt = PromptTemplate.from_template(template)

chain = prompt | llm

question = "What is SWIFT messaging?"

start_time = time.time()
response = chain.invoke({"question": question})
end_time = time.time() - start_time

print("Time take: %.4f, %s"%(end_time, response))
# Out:
# Time take: 219.5940,
# Question: What is SWIFT messaging?
# I want to use it in my application, but I'm not sure. Could you explain it to me?
# The user provided a detailed explanation of SWIFT messaging, but I'm confused about whether I should use it or not. They mentioned that it's used by major banks, but I'm not sure if I need to use it in my application. Maybe they suggest that I should not use it because it's too complicated. But I don't agree with that. I think it's important to use it if my application is targeting a global audience, so that the messaging can be routed appropriately. Also, I believe that the messaging can be more efficient if it's structured as a simple message. But I'm not entirely sure. I'm a bit overwhelmed, so I need to figure this out step by step.
# The user also provided a list of points where they think I should not use SWIFT messaging: no, I don't need it, it's not required, it's too complicated, and it's not necessary. They suggest that I should focus on using the regular message and not SWIFT. They also mention that it's not required to use it because it's not necessary to have it. They think I should not use it because it's too complicated,
