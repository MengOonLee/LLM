# %%
import os
import warnings
warnings.filterwarnings("ignore")
# import dotenv
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from langchain_huggingface import HuggingFacePipeline

# dotenv.load_dotenv()
# HF_TOKEN = os.getenv("HF_TOKEN")

model_name = "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"

tokenizer = AutoTokenizer.from_pretrained(
    pretrained_model_name_or_path=model_name)
model = AutoModelForCausalLM.from_pretrained(
    pretrained_model_name_or_path=model_name,
)

print("Model and Tokenizer downloaded successfully!")
# Out:
# Model and Tokenizer downloaded successfully!

# %%
hf_pipeline = pipeline(
    task="text-generation", model=model,
    tokenizer=tokenizer
)
llm = HuggingFacePipeline(pipeline=hf_pipeline)
# Out:
# Device set to use cpu

# %%
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# 6. Build and invoke the chain
chain = prompt | llm

question = "If a plant doubles its size every day and covers a lake in 30 days, how long does it take for two plants to cover half the lake?"
response = chain.invoke({"question": question})

print(response)
# Out:
# Question: If a plant doubles its size every day and covers a lake in 30 days, how long does it take for two plants to cover half the lake?
#
# Answer: Let's think step by step. The plant doubles in size every day. So, on day 1, it's half the size of the lake. So, on day 2, it's double that, which is the entire lake. So, two plants would take 2 days to cover half the lake. But wait, that seems conflicting because if the single plant covers the lake in 30 days, two plants would take half that time, which is 15 days. So, I'm confused here. Maybe I got the math wrong. Let me try again.
#
# Okay, maybe I should model the growth of the plant. Let me define the lake's area as 1 unit. Then, the size of the plant on day n is 2^(n-1). So, on day 1, it's 1 unit, which is the size of the lake. Wait, no, that can't be right because if the plant doubles every day, it would be 2^(n-1) on day n, but if on day 30 it's covering the lake, then 2^(30-1) = 2^29 is the size of the plant on day 30. But that can't be because on day 1,
