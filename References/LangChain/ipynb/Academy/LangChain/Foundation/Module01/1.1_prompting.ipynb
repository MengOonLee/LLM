# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/LLM/blob/main/References/LangChain/ipynb/Academy/LangChain/Foundation/Module01/1.1_prompting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Basic prompting

# %%
# %%bash
# apt install -y zstd
# apt install -y pciutils lshw
# curl -fsSL https://ollama.com/install.sh | sh
# pip install --no-cache-dir -qU \
#     langchain langgraph langchain-core \
#     langchain-community langchain-ollama ollama

# %%
# !nohup ollama serve &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# !ollama pull gpt-oss:20b

# %%
import warnings
warnings.filterwarnings('ignore')
import dotenv

_ = dotenv.load_dotenv(dotenv_path=".env", override=True)

# %%
import langchain_ollama
from langchain import agents, messages
import time

model = langchain_ollama.ChatOllama(
    model="gpt-oss:20b",
    temperature=1.0
)

agent = agents.create_agent(model=model)

question = messages.HumanMessage(content="""
    What's the capital of the moon?
""")

start_time = time.time()
response = agent.invoke(input={"messages": [question]})
print(response['messages'][1].content)
end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))

# %%
import langchain_ollama
from langchain import agents, messages
import pprint

model = langchain_ollama.ChatOllama(
    model="gpt-oss:20b",
    temperature=1.0
)

system_prompt = """
    You are a science fiction writer, create a capital city at the
    users request.
"""

scifi_agent = agents.create_agent(
    model=model,
    system_prompt=system_prompt
)

question = messages.HumanMessage(content="""
    What's the capital of the moon?
""")

response = scifi_agent.invoke(input={"messages": [question]})

print(response['messages'][1].content)
# Out:
# ('**The Moon’s Capital: Luna\u202fPrimus**\n'
#  '\n'
#  '*Location:*  \n'
#  'Luna\u202fPrimus is perched on the far side of the Moon, tucked beneath the '
#  'ridge of the **Mare Tranquillitatis** (Sea of Tranquility). The city’s main '
#  'orbital hub—**Selenis Orbital**—hovers above the crater, linked by a lattice '
#  'of transparent fiber-optic pylons that crisscross the regolith. The '
#  'dome‑covered metropolis sits in a shallow basin formed by the ancient impact '
#  'of **Luna‑1** and the subsequent collapse of the crater rim.\n'
#  '\n'
#  '*Architecture & Environment:*  \n'
#  'The city is a seamless blend of organic forms and high‑tech engineering. '
#  '**Celestial Spires** rise from the lunar surface like twin pillars of glass '
#  'and titanium, each spire housing a vertical garden of genetically engineered '
#  'flora that thrives in low gravity and high radiation. The spires serve both '
#  'as administrative centers and as “greenhouses” where bio‑engineered plants '
#  'generate oxygen and produce edible crops.\n'
#  '\n'
#  'Beneath the domes, a network of **regolith‑milled corridors** runs like a '
#  'circulatory system, filled with self‑cleaning algae panels that produce '
#  'clean air and capture CO₂. The city’s streets are laid out in a radial '
#  'pattern, converging on the central **Helios Plaza**—a gigantic, translucent '
#  'atrium that houses the lunar council chambers, the **Selenic Assembly**.\n'
#  '\n'
#  '*Governance:*  \n'
#  'Luna\u202fPrimus is the seat of the **Lunar Federation**, a democratic body '
#  'representing colonies across the lunar surface. The **Selenic Assembly** '
#  'meets quarterly in the Helios Plaza to pass laws, coordinate resource '
#  'sharing, and negotiate with the Earth‑bound United Coalition. The city’s '
#  'mayor, the **Chancellor of the Moon**, is elected by a direct vote of all '
#  'lunar citizens, who are registered through a network of biometric '
#  'identification chips embedded in their implants.\n'
#  '\n'
#  '*Culture & Society:*  \n'
#  'Life on Luna\u202fPrimus is a blend of Earth heritage and new lunar '
#  'traditions. The city hosts the annual **“Lunar Light Festival,”** when '
#  'residents hang phosphorescent lanterns that float in the air—thanks to the '
#  'city’s magnetic levitation system—creating a sky of glowing constellations. '
#  'The **Selenic Academy** provides education in quantum physics, terraforming, '
#  'and xenobiology, ensuring the next generation is equipped to expand '
#  'humanity’s reach beyond the Moon.\n'
#  '\n'
#  '*Defense & Security:*  \n'
#  'The city’s security is maintained by the **Lunar Guard**, a volunteer '
#  'militia trained in zero‑gravity combat and asteroid‑impact response. A '
#  'sophisticated system of **laser‑shield domes** protects the city’s '
#  'infrastructure from micrometeoroids, while the orbital station **Selenis '
#  'Orbital** keeps watch for any hostile activity in the near‑space '
#  'environment.\n'
#  '\n'
#  '*Why Luna\u202fPrimus?*  \n'
#  'Founded after the first moon colony was established in the late 22nd '
#  'century, Luna\u202fPrimus grew into the political and cultural heart of '
#  'humanity’s lunar presence. Its name—meaning “Moon First” in Latin—reminds '
#  'its citizens that this city is the gateway to the cosmos, the starting point '
#  'for the next chapters of human expansion.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '*That is the capital of the Moon, as imagined by the collective mind of '
#  'humanity in the near future. Would you like to hear more about its history, '
#  'or perhaps explore a different lunar settlement?*')

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
