# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/LLM/blob/main/References/LangChain/LangChainAcademy/LangChain/Foundation/CreateAgent/ipynb/1.1_foundational_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# pip install --no-cache-dir -qU \
#     langchain langgraph langchain-core langchain-community \
#     langchain-ollama

# %%
import warnings
warnings.filterwarnings("ignore")
from dotenv import load_dotenv

_ = load_dotenv(dotenv_path=".env", override=True)

# %% [markdown]
# ## Initialising and invoking a model

# %%
import os
from langchain.chat_models import init_chat_model

llm = init_chat_model(
    model="qwen3.5:cloud",
    model_provider="ollama",
    base_url="https://ollama.com",
    api_key=os.environ["OLLAMA_API_KEY"],
    temperature=0
)

# %%
import os
import time
import pprint

start_time = time.time()
response = llm.invoke(input="What's the capital of the Moon?")
end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))

print(response.content)
pprint.pprint(response.response_metadata)
# Out:
# Time taken: 3.07s seconds
# The Moon does not have a capital.
#
# It is not a country or a sovereign nation, so it has no government, no population, and no cities. It is a natural satellite that orbits Earth.
# {'created_at': '2026-03-24T14:29:55.287428096Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 432,
#  'eval_duration': None,
#  'load_duration': None,
#  'logprobs': None,
#  'model': 'qwen3.5:cloud',
#  'model_name': 'qwen3.5:cloud',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 19,
#  'prompt_eval_duration': None,
#  'total_duration': 2534738330}

# %% [markdown]
# ## Initialising and invoking an agent

# %%
import os
import time
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=llm)
messages = [HumanMessage(content="What's the capital of the Moon?")]

start_time = time.time()
response = agent.invoke(input={"messages": [question]})
end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))

for m in response['messages']:
    m.pretty_print()

# %%
import os
import time
from langchain.agents import create_agent
from langchain.messages import HumanMessage, AIMessage

agent = create_agent(model=llm)
messages = [
    HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City.")
]

start_time = time.time()
response = agent.invoke(input={"messages": messages})
end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))

for m in response['messages']:
    m.pretty_print()
# Out:
# Time taken: 14.37s seconds
# ================================ Human Message =================================
#
# What's the capital of the Moon?
# ================================== Ai Message ==================================
#
# The capital of the Moon is Luna City.
# ================================ Human Message =================================
#
# Interesting, tell me more about Luna City.
# ================================== Ai Message ==================================
#
# I need to correct my previous statement. Actually, **the Moon does not have a capital city.**
#
# Because the Moon is a celestial body and not a sovereign nation, it has no government, no population, and therefore no capital. My previous answer referred to a fictional concept rather than reality.
#
# **"Luna City" in Science Fiction**
# The idea of a "Luna City" is a popular trope in science fiction. It often appears as humanity's first permanent settlement on the Moon. Some notable examples include:
#
# *   **Robert Heinlein's *The Moon Is a Harsh Mistress*:** In this classic novel, Luna serves as a penal colony for Earth's governments and eventually becomes a self-governing society.
# *   **Video Games and Media:** Variations of Luna City appear in franchises like *Destiny*, *Civilization*, and various anime series, usually depicted as a domed metropolis or underground habitat.
#
# **Real Plans for Lunar Habitation**
# While there is no city today, space agencies like NASA (with the **Artemis program**) and the Chinese National Space Administration (CNSA) have proposed plans for future lunar bases. These concepts often involve habitats near the lunar south pole, where water ice has been detected, but these are still in the planning or early development stages.
#
# So, while Luna City is a fascinating idea for the future, for now, it exists only in stories!

# %% [markdown]
# ## Streaming Output

# %%
import os
import time
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=llm)
messages = [HumanMessage(content="""
    Tell me all about Luna City, the capital of the Moon.
""")]

start_time = time.time()
for token, metadata in agent.stream(
    input={"messages": messages},
    stream_mode="messages"
):
    # token is a message chunk with token content
    # metadata contains which node produced the token
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token

end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))
# Out:
# I need to start with a very important clarification: **Luna City does not exist.**
#
# There is currently no human settlement, city, or capital on the Moon. The Moon is uninhabited, has no government, and belongs to no nation. Consequently, there is no "capital."
#
# However, the idea of "Luna City" is a very popular concept in science fiction, futurism, and space exploration proposals. Here is a breakdown of where the idea comes from, the reality of lunar exploration, and why the term persists.
#
# ### 1. The Reality: The Moon Today
# *   **Population:** 0 (permanent residents).
# *   **Government:** None.
# *   **Status:** The Moon is governed by the **Outer Space Treaty of 1967**. This international agreement states that no nation can claim sovereignty over the Moon or any other celestial body. It is designated as the "province of all mankind."
# *   **Visitors:** Only 12 humans have ever walked on the Moon (during NASA's Apollo missions between 1969 and 1972). No one has been there since 1972.
#
# ### 2. Where the Name "Luna City" Comes From
# The term is deeply rooted in pop culture and speculative architecture:
#
# *   **Science Fiction:**
#     *   **Robert Heinlein:** In his classic novel *The Moon Is a Harsh Mistress* (1966), the lunar colony is called "Luna," and its capital city is often referred to in fan discussions as Luna City (though in the book, the main city is "City of Congress" or simply "Luna").
#     *   **Video Games & Movies:** Many fictional universes feature a lunar capital. For example, in the *Earth 2160* game series, or various *Star Trek* expanded universes, Luna City is the administrative center of Earth's off-world colonies.
# *   **Architectural Concepts:**
#     *   Over the decades, architects and futurists (such as those in the L5 Society or modern concepts by NASA contractors) have drawn up designs for permanent lunar bases. Some of these conceptual renderings are colloquially named "Luna City" to represent a large, domed metropolitan area.
#
# ### 3. Real Plans for a Lunar Base
# While "Luna City" isn't real, space agencies are actively planning for a permanent human presence.
#
# *   **NASA's Artemis Program:** The current goal is to return humans to the Moon by 2025/2026 and establish a **long-term presence** by the end of the decade.
# *   **The Lunar Gateway:** A small space station planned to orbit the Moon, serving as a staging point for landers.
# *   **Artemis Base Camp:** A proposed surface habitat near the lunar South Pole. This is the closest real-world equivalent to the idea of a "city," though it will start as a small scientific outpost.
# *   **International Lunar Research Station (ILRS):** A joint project led by China (CNSA) and Russia (Roscosmos) with other partners, aiming to build a robotic and eventually crewed base on the lunar surface.
#
# ### 4. Why There Can't Be a "Capital"
# Even if humans build a city on the Moon in the future, calling it a "capital" implies political sovereignty, which is currently illegal under international space law.
#
# *   **No Ownership:** Because no country owns the Moon, no country can designate a capital there.
# *   **Jurisdiction:** Any base built on the Moon would likely fall under the jurisdiction of the country or company that built it (similar to how a US module on the ISS is US territory), but the land itself remains neutral.
# *   **Future Governance:** If a large colony ever forms, it would likely need a new legal framework. Some futurists speculate about lunar independence (as seen in Heinlein's books), but that is purely theoretical.
#
# ### 5. Common Misconceptions
# If you have heard about Luna City as a factual place, it may stem from:
# *   **Satire or Fake News:** Sometimes satirical articles about space colonization are mistaken for real news.
# *   **Conspiracy Theories:** There are fringe theories claiming secret bases already exist (often called "Secret Space Programs"), but there is zero evidence to support these claims.
# *   **Confusion with "Luna" Missions:** The Soviet Union had a series of robotic spacecraft named "Luna" (e.g., Luna 2, Luna 9) that landed on the Moon in the 1960s and 70s. This sometimes leads to confusion about a place named Luna.
#
# ### Summary
# **Luna City is a fictional or conceptual location, not a real one.**
#
# *   **Fact:** The Moon is barren, airless, and uninhabited.
# *   **Future:** Humans plan to build bases there within the next 10–20 years.
# *   **Fiction:** "Luna City" remains a staple of sci-fi storytelling, representing humanity's expansion into the stars.
#
# If you are interested in the *future* of lunar habitation, looking into the **Artemis Base Camp** plans or the **ESA's Moon Village** concept will give you accurate information about what a real lunar settlement might look like.Time taken: 20.95s seconds
