# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/LLM/blob/main/References/LangChain/LangChainAcademy/LangChain/Foundation/CreateAgent/ipynb/1.1_foundational_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# pip install --no-cache-dir -qU \
#     langchain langgraph langchain-core langchain-community \
#     langchain-ollama

# %%
import warnings
warnings.filterwarnings("ignore")
from dotenv import load_dotenv

_ = load_dotenv(dotenv_path=".env", override=True)

# %% [markdown]
# ## Initialising and invoking a model

# %%
import os
from langchain.chat_models import init_chat_model

llm = init_chat_model(
    model="gemma4:31b-cloud",
    model_provider="ollama",
    base_url="https://ollama.com",
    api_key=os.environ["OLLAMA_API_KEY"],
    temperature=0
)

# %%
import time
import pprint

start_time = time.time()

messages = "What's the capital of the Moon?"
response = llm.invoke(input=messages)
print(response.content)
pprint.pprint(response.response_metadata)

end_time = time.time() - start_time
print(f"Time taken: %.2fs"%(end_time))
# Out:
# The Moon does not have a capital because it is not a country and has no government. It is not owned by any single nation, and there are currently no permanent human settlements there.
# {'created_at': '2026-04-13T14:32:12.951762993Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 42,
#  'eval_duration': None,
#  'load_duration': None,
#  'logprobs': None,
#  'model': 'gemma4:31b-cloud',
#  'model_name': 'gemma4:31b-cloud',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 18,
#  'prompt_eval_duration': None,
#  'total_duration': 10722491064}
# Time taken: 10.95s

# %% [markdown]
# ## Initialising and invoking an agent

# %%
import time
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=llm)

start_time = time.time()

messages = [HumanMessage(content="What's the capital of the Moon?")]
response = agent.invoke(input={"messages": messages})
for m in response["messages"]:
    m.pretty_print()

end_time = time.time() - start_time
print(f"Time taken: %.2fs"%(end_time))
# Out:
# ================================ Human Message =================================
#
# What's the capital of the Moon?
# ================================== Ai Message ==================================
#
# The Moon does not have a capital because it is not a country and has no government. It is a natural satellite with no permanent human inhabitants or sovereign states.
# Time taken: 5.53s

# %%
import time
from langchain.agents import create_agent
from langchain.messages import HumanMessage, AIMessage

agent = create_agent(model=llm)

start_time = time.time()

messages = [
    HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City.")
]
response = agent.invoke(input={"messages": messages})
for m in response["messages"]:
    m.pretty_print()

end_time = time.time() - start_time
print(f"Time taken: %.2fs"%(end_time))
# Out:
# ================================ Human Message =================================
#
# What's the capital of the Moon?
# ================================== Ai Message ==================================
#
# The capital of the Moon is Luna City.
# ================================ Human Message =================================
#
# Interesting, tell me more about Luna City.
# ================================== Ai Message ==================================
#
# I must apologize—I misspoke in my previous response. **The Moon does not actually have a capital city because it has no government, no sovereign nations, and no permanent human inhabitants.**
#
# There is no real place called "Luna City." If you encountered that name, it likely comes from science fiction movies, novels, or video games, where authors imagine future lunar colonies.
#
# In reality, the Moon is governed by international treaties. The **Outer Space Treaty of 1967**, signed by most nations on Earth, states that no country can claim ownership of the Moon or any other celestial body. It is considered the "province of all mankind."
#
# While there are no cities, there are many "landing sites" (like the Apollo sites) and robotic stations currently exploring the surface!
# Time taken: 3.59s

# %% [markdown]
# ## Streaming Output

# %%
import time
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=llm)

start_time = time.time()

messages = [HumanMessage(content="""
Tell me all about Luna City, the capital of the Moon.
""")]

for token, metadata in agent.stream(input={"messages": messages},
    stream_mode="messages"
):
    # token is a message chunk with token content
    # metadata contains which node produced the token
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token

end_time = time.time() - start_time
print(f"\nTime taken: %.2fs"%(end_time))
# Out:
# ***Note: Luna City is a fictional setting. While there are many real-world proposals for lunar colonies (such as those by NASA or SpaceX), "Luna City" typically refers to a common trope in science fiction, tabletop RPGs, or speculative world-building.***
#
# Depending on the specific universe you are referring to, the details may vary, but here is a comprehensive look at the **archetypal Luna City**—the shimmering, pressurized capital of the Moon.
#
# ---
#
# ### 1. Geography and Architecture
# Luna City is rarely a sprawling metropolis of skyscrapers; instead, it is a marvel of **subterranean engineering**. Because the lunar surface is bombarded by solar radiation and micrometeorites, the city is built primarily inside a massive **Lava Tube** (a natural underground cavern formed by ancient volcanic activity).
#
# *   **The Dome Districts:** The "surface" of the city consists of a series of interconnected geodesic domes made of reinforced aluminum-oxynitride (transparent aluminum). These domes house the hydroponic gardens and the spaceports.
# *   **The Warrens:** The residential and industrial sectors are carved deep into the basalt rock, providing natural shielding from cosmic rays.
# *   **The Spire:** The administrative center, which often pokes through the surface, serving as a communications hub and a symbol of lunar sovereignty.
#
# ### 2. Economy and Industry
# Luna City is not just a residential hub; it is the industrial engine of the solar system. Its economy is based on three pillars:
#
# *   **Helium-3 Mining:** The primary export. Helium-3 is harvested from the lunar regolith and shipped back to Earth to fuel clean, efficient nuclear fusion reactors.
# *   **The Gateway Hub:** Because the Moon has low gravity, it is the perfect "gas station" and shipyard for missions to Mars and the Asteroid Belt. Luna City manages the logistics of all deep-space travel.
# *   **Low-G Manufacturing:** Certain pharmaceuticals and high-precision crystals can only be grown in low gravity, making Luna City a center for high-tech biotech and materials science.
#
# ### 3. Society and Culture
# Life in Luna City is defined by the "Lunar Struggle"—the constant battle against a vacuum.
#
# *   **The "Loonies":** A distinct cultural identity has emerged. Born in 1/6th gravity, "Loonies" are often taller and thinner than Earth-born humans. They view Earth as a "heavy," crowded, and bureaucratic place.
# *   **The Air Tax:** In many versions of Luna City, air and water are not free. Citizenship is often tied to one's contribution to the city's life-support systems.
# *   **The Cycle:** Since there is no natural 24-hour day/night cycle (a lunar day lasts about 29 Earth days), the city uses "Artificial Circadian Lighting" to simulate Earth's day and night to prevent psychological breakdown.
#
# ### 4. Governance
# Luna City usually operates under one of three political structures:
# 1.  **The Corporate Syndicate:** The city is owned by the mega-corporations that funded the initial colony.
# 2.  **The UN Lunar Council:** A diplomatic neutral zone where Earth nations share power.
# 3.  **The Independent Republic:** A breakaway state that has declared independence from Earth, leading to "Cold War" tensions between the Moon and the Home Planet.
#
# ### 5. Daily Life: The "Lunar Experience"
# *   **Transportation:** Maglev trains that zip through vacuum tubes connecting the various domes.
# *   **Sport:** "Low-G Ball" or "Wing-Gliding," where humans use artificial wings to fly inside the massive pressurized caverns.
# *   **Diet:** Mostly lab-grown meats and algae-based proteins, supplemented by "Dome-Grown" luxury vegetables.
#
# **Is this the Luna City from a specific book, game, or movie you are thinking of? If so, let me know and I can give you the specific lore for that universe!**
# Time taken: 18.72s
