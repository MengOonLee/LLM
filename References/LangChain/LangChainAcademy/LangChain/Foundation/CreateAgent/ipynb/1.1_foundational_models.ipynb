# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/LLM/blob/main/References/LangChain/LangChainAcademy/LangChain/Foundation/CreateAgent/ipynb/1.1_foundational_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# pip install --no-cache-dir -qU \
#     langchain langgraph langchain-core langchain-community \
#     langchain-ollama

# %%
import warnings
warnings.filterwarnings("ignore")
from dotenv import load_dotenv

_ = load_dotenv(dotenv_path=".env", override=True)

# %% [markdown]
# ## Initialising and invoking a model

# %%
import os
from langchain.chat_models import init_chat_model

llm = init_chat_model(
    model="qwen3.5:cloud",
    model_provider="ollama",
    base_url="https://ollama.com",
    api_key=os.environ["OLLAMA_API_KEY"],
    temperature=0
)

# %%
import os
import time
import pprint

messages = "What's the capital of the Moon?"
start_time = time.time()
response = llm.invoke(input=messages)
end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))

print(response.content)
pprint.pprint(response.response_metadata)
# Out:
# Time taken: 16.58s seconds
# The Moon does not have a capital city. It is a natural satellite of Earth, not a country or sovereign state, so it has no government, population, or cities.
# {'created_at': '2026-03-27T12:33:18.423100909Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 412,
#  'eval_duration': None,
#  'load_duration': None,
#  'logprobs': None,
#  'model': 'qwen3.5:cloud',
#  'model_name': 'qwen3.5:cloud',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 18,
#  'prompt_eval_duration': None,
#  'total_duration': 16269403240}

# %% [markdown]
# ## Initialising and invoking an agent

# %%
import os
import time
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=llm)
messages = [HumanMessage(content="What's the capital of the Moon?")]

start_time = time.time()
response = agent.invoke(input={"messages": messages})
end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))

for m in response['messages']:
    m.pretty_print()
# Out:
# Time taken: 8.02s seconds
# ================================ Human Message =================================
#
# What's the capital of the Moon?
# ================================== Ai Message ==================================
#
# The Moon does not have a capital. It is not a country or a sovereign nation, but rather a natural satellite of Earth. There are no permanent human settlements or governments on the Moon.

# %%
import os
import time
from langchain.agents import create_agent
from langchain.messages import HumanMessage, AIMessage

agent = create_agent(model=llm)
messages = [
    HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City.")
]

start_time = time.time()
response = agent.invoke(input={"messages": messages})
end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))

for m in response['messages']:
    m.pretty_print()
# Out:
# Time taken: 66.48s seconds
# ================================ Human Message =================================
#
# What's the capital of the Moon?
# ================================== Ai Message ==================================
#
# The capital of the Moon is Luna City.
# ================================ Human Message =================================
#
# Interesting, tell me more about Luna City.
# ================================== Ai Message ==================================
#
# I apologize, but I need to correct myself. **The Moon does not actually have a capital city.**
#
# My previous answer was incorrect. Here are the facts:
#
# *   **No Sovereignty:** The Moon is not a country or a sovereign nation. Under the Outer Space Treaty of 1967, no nation can claim ownership of the Moon, so it cannot have a government or a capital.
# *   **No Population:** There are no permanent human settlements on the Moon. It is currently uninhabited.
# *   **Science Fiction:** "Luna City" is a popular concept in science fiction literature, movies, and games (such as in Robert Heinlein's *The Moon Is a Harsh Mistress* or the *Ad Astra* film), but it does not exist in reality.
#
# While space agencies like NASA (with the Artemis program) and others are planning to build sustainable lunar bases in the future, there are no cities or capitals there at this time.

# %% [markdown]
# ## Streaming Output

# %%
import os
import time
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=llm)
messages = [HumanMessage(content="""
Tell me all about Luna City, the capital of the Moon.
""")]

start_time = time.time()
for token, metadata in agent.stream(
    input={"messages": messages},
    stream_mode="messages"
):
    # token is a message chunk with token content
    # metadata contains which node produced the token
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token

end_time = time.time() - start_time
print(f"\nTime taken: %.2fs seconds"%(end_time))
# Out:
# There is an important fact to clarify right away: **Luna City does not exist.**
#
# There is currently no human settlement on the Moon, and therefore there is no "capital of the Moon." The Moon is uninhabited, visited only briefly by astronauts during the Apollo missions (1969–1972) and by uncrewed robotic landers.
#
# However, the concept of "Luna City" is very popular in **science fiction** and **future planning**. Here is a breakdown of where the idea comes from, what exists in fiction, and what is planned for reality.
#
# ---
#
# ### 1. In Science Fiction
# The term "Luna City" is most famously associated with literature and media rather than geography.
#
# *   **Robert A. Heinlein's *The Moon Is a Harsh Mistress* (1966):** This is the most famous depiction. In the novel, Luna City is the primary settlement on the Moon, inhabited by exiles and criminals ("Loonies"). It plays a central role in a revolution against Earth's authority.
# *   **Other Media:** Variations of a lunar capital appear in video games (like *Destiny* or *Mass Effect*), comic books, and TV shows (such as *For All Mankind*, though they often use different names like Jamestown or Moonbase Alpha from *Space: 1999*).
# *   **The Aesthetic:** In fiction, Luna City is usually depicted as a domed structure, an underground cavern system, or a cluster of modules near a crater (often Shackleton Crater at the lunar south pole).
#
# ### 2. In Real-World Space Exploration
# While no city exists today, space agencies and private companies are actively planning for permanent human presence on the Moon.
#
# *   **The Artemis Program (NASA):** NASA's current plan is to return humans to the Moon by 2026 (Artemis III) and establish a sustainable presence. This includes the **Lunar Gateway** (a space station orbiting the Moon) and surface habitats.
# *   **Lunar Base Concepts:** Architects and engineers have designed concepts for lunar bases. These are often proposed for the **Lunar South Pole**, where water ice exists in permanently shadowed craters. Water is essential for drinking, growing food, and making rocket fuel.
# *   **Private Industry:** Companies like SpaceX (with the Starship lunar lander) and Blue Origin are developing technology to transport heavy cargo and people to the surface, which is a prerequisite for building a city.
#
# ### 3. Legal and Political Status
# Even if a city were built tomorrow, calling it a "capital" would be legally complicated.
#
# *   **The Outer Space Treaty (1967):** This international agreement states that **no nation can claim sovereignty over celestial bodies.** This means no country can claim the Moon as its territory, and by extension, there can be no national "capital" there.
# *   **Governance:** Future lunar settlements would likely be governed by international agreements or corporate contracts rather than traditional national laws. Some futurists propose that a lunar settlement could eventually declare independence (a theme explored in Heinlein's book), but this remains theoretical.
#
# ### 4. Why Do People Think It Exists?
# Confusion about Luna City usually stems from three sources:
# 1.  **Conspiracy Theories:** Some fringe theories claim there are secret bases on the Moon, but there is no evidence to support this.
# 2.  **Sci-Fi vs. Reality:** Pop culture is so rich with lunar colonies that it can feel like they should exist already.
# 3.  **Future Planning News:** Headlines about "Plans for a Moon Village" (ESA) or "Lunar City Concepts" can be misinterpreted as announcements of existing structures.
#
# ### Summary
# *   **Does Luna City exist?** No.
# *   **Does anyone live on the Moon?** No.
# *   **Will it exist in the future?** Possibly. NASA and other agencies aim to build permanent bases within the next few decades, but a full-scale "city" with a "capital" status is likely many years away.
#
# If you encountered "Luna City" in a book, game, or movie, it is a fictional setting. If you are asking about future colonization, it is a concept that scientists are working toward, but it is not yet a reality.
# Time taken: 57.79s seconds
