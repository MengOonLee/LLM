# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/LLM/blob/main/References/LangChain/LangChainAcademy/LangChain/Foundation/CreateAgent/ipynb/1.1_foundational_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# pip install --no-cache-dir -qU \
#     langchain langgraph langchain-core \
#     langchain-community langchain-ollama

# %%
import warnings
warnings.filterwarnings("ignore")
import dotenv

_ = dotenv.load_dotenv(dotenv_path=".env", override=True)

# %% [markdown]
# ## Initialising and invoking a model

# %%
import langchain_ollama
import os
import time
import pprint

model = langchain_ollama.ChatOllama(
    model="gpt-oss:120b-cloud",
    base_url="https://ollama.com",
    headers={"Authorization": f"Bearer {os.environ["OLLAMA_API_KEY"]}"},
    temperature=1.0, max_tokens=128
)

start_time = time.time()
response = model.invoke(input="""
    What's the capital of the Moon?
""")
end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))

print(response.content)
pprint.pprint(response.response_metadata)
# Out:
# Time taken: 3.77s seconds
# The Moon isn’t a country, a state, or even a city—it’s a natural satellite of Earth—so it doesn’t have an official “capital” in the way nations do.
#
# **What people sometimes call “the capital of the Moon”**
#
# | Source / Context | Name (often cited) | Why it gets the nickname |
# |------------------|-------------------|---------------------------|
# | **Science‑fiction & Pop Culture** | **Luna City** (or “Lunopolis”) | A fictional megacity that appears in various novels, movies, and games as the Moon’s primary settlement. |
# | **NASA history** | **Tranquility Base** | The site where Apollo 11 landed on 20 July 1969. In a tongue‑in‑cheek sense, some people refer to it as “the first human settlement on the Moon,” and it’s the most historically significant spot. |
# | **Proposed future colonies** | **Artemis Base Camp** (planned near the lunar south pole) | NASA’s Artemis program envisions a long‑term foothold there. If a permanent human outpost ever materializes, the name could become the de‑facto “capital.” |
# | **Science‑fiction literature** | **New Hope** (in Robert A. Heinlein’s “The Moon Is a Harsh Mistress”) | In Heinlein’s classic, the lunar colony’s main administrative center is called the “Lunar Authority” with its hub in the lunar city of New Hope. |
#
# **Bottom line:**
# - **No legal or geopolitical capital exists today.** The Moon has no government, no permanent civilian population, and therefore no official seat of power.
# - **If you’re looking for a symbolic or cultural “capital,”** the most common candidates are the historic Apollo 11 landing site (Tranquility Base) or the fictional Luna City that appears in many stories.
#
# So, while we can point to noteworthy locations, the Moon officially has *no* capital. 🚀🌕
# {'created_at': '2026-03-07T15:27:29.018429792Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 502,
#  'eval_duration': None,
#  'load_duration': None,
#  'logprobs': None,
#  'model': 'gpt-oss:120b',
#  'model_name': 'gpt-oss:120b',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 76,
#  'prompt_eval_duration': None,
#  'total_duration': 3441878961}

# %% [markdown]
# ## Initialising and invoking an agent

# %%
import os
import time
import langchain_ollama
from langchain import agents, messages

model = langchain_ollama.ChatOllama(
    model="gpt-oss:120b-cloud",
    base_url="https://ollama.com",
    headers={"Authorization": f"Bearer {os.environ["OLLAMA_API_KEY"]}"},
    temperature=1.0, max_tokens=128
)
agent = agents.create_agent(model=model)

start_time = time.time()
response = agent.invoke(
    input={"messages": [
        messages.HumanMessage(content="""
            What's the capital of the Moon?
        """)
    ]}
)
end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))

for m in response['messages']:
    m.pretty_print()
# Out:
# Time taken: 6.94s seconds
# ================================ Human Message =================================
#
#
#             What's the capital of the Moon?
#
# ================================== Ai Message ==================================
#
# The short answer is **the Moon doesn’t have a capital**—it isn’t a sovereign nation, a state, or even a colony with an official government, so there’s no official “capital city” to name.
#
# ### Why there’s no capital
#
# | Factor | Explanation |
# |--------|--------------|
# | **Political status** | The Moon is considered *international* territory under the 1967 Outer Space Treaty (OST). No single country claims sovereign ownership, and the treaty forbids any nation from claiming “national territory” on the Moon. |
# | **No permanent civilian population** | All human presence on the Moon so far has been short‑term scientific missions (Apollo, Luna, Chang’e, etc.). There’s no permanent settlement that could evolve into a capital. |
# | **No government structure** | A capital is usually the seat of a government. The Moon has no governing body, so the concept simply doesn’t apply. |
#
# ### What “capital‑like” places do exist (or are imagined)?
#
# | Category | Example | Notes |
# |----------|----------|-------|
# | **Historical landing sites** | *Tranquility Base* (Apollo 11) | Often called a “base” but it was just the landing spot of the first crewed Moon landing. |
# | **Future proposed bases** | *Artemis Base Camp* (NASA’s planned lunar outpost) | If the Artemis program eventually creates a permanent settlement, the first major habitat could become a de‑facto “capital” for lunar activities. |
# | **Science fiction cities** | *Luna City*, *Selene City*, *New New York* | Appear in books, movies, and games (e.g., *The Moon is a Harsh Mistress* by Robert A. Heinlein, *Space Opera* by Christopher Rowley, the video game *Moonbase Alpha*). |
# | **Real‑world concept studies** | *Moon Village* (ESA) | The European Space Agency envisions an international “Moon Village” that could host research labs, habitats, and commercial facilities. It’s not a city yet, but it’s the closest real‑world “central hub” concept. |
#
# ### If you’re looking for a fun answer
#
# - **In popular culture:** The capital of the Moon is often called **“Luna City”** (used in many sci‑fi settings).
# - **In jokes:** “The capital of the Moon is **‘Crescent City’** because it’s always in a ‘phase’!”
# - **In a tongue‑in‑cheek way:** The Moon’s “capital” could be considered **the “Sea of Tranquility”** because it’s where humanity first set foot and made history.
#
# ### What’s likely to happen next?
#
# - **Artemis program (NASA, 2020s‑2030s):** Plans to land the first woman and the next man on the lunar South Pole by the mid‑2020s, followed by a small Gateway outpost and eventually a surface “lunar base.” If that base expands into a larger settlement, a particular habitat (or cluster of habitats) could be informally dubbed the “capital.”
# - **International collaborations:** Agencies like ESA, Roscosmos, CNSA, JAXA, and private companies (SpaceX, Blue Origin, etc.) are all discussing lunar infrastructure. A multi‑national “Moon Village” could evolve, and the administrative hub of that village might someday be called the capital—though that’s still speculative.
#
# ### TL;DR
#
# - **Current reality:** No capital—no government, no permanent civilian city.
# - **Future possibility:** A lunar base or “Moon Village” could eventually serve as a central hub, perhaps earning an informal “capital” title.
# - **Fictional fun:** Luna City, Selene City, or Tranquility Base are common fictional “capitals” of the Moon.
#
# If you were hoping for a specific name from a story or a proposed NASA project, let me know, and I can dive deeper into that particular reference!

# %%
import os
import time
import langchain_ollama
from langchain import agents, messages

model = langchain_ollama.ChatOllama(
    model="gpt-oss:120b-cloud",
    base_url="https://ollama.com",
    headers={"Authorization": f"Bearer {os.environ["OLLAMA_API_KEY"]}"},
    temperature=1.0, max_tokens=128
)
agent = agents.create_agent(model=model)

start_time = time.time()
response = agent.invoke(
    input={"messages": [
        messages.HumanMessage(content="""
            What's the capital of the Moon?
        """),
        messages.AIMessage(content="""
            The capital of the Moon is Luna City.
        """),
        messages.HumanMessage(content="""
            Interesting, tell me more about Luna City.
        """)
    ]}
)
end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))

for m in response['messages']:
    m.pretty_print()
# Out:
# Time taken: 14.00s seconds
# ================================ Human Message =================================
#
#
#             What's the capital of the Moon?
#
# ================================== Ai Message ==================================
#
#
#             The capital of the Moon is Luna City.
# ================================ Human Message =================================
#
#
#             Interesting, tell me more about Luna City.
#
# ================================== Ai Message ==================================
#
# **Luna City – The Moon’s First Capital**
#
# *Luna City* is the thriving, international hub that stands as the de‑facto capital of humanity’s permanent presence on the Moon. Though the Moon has no native governments, Luna City functions as the political, scientific, cultural, and commercial center for all lunar activities. Below is a snapshot of what makes Luna City unique.
#
# ---
#
# ## 1. Location & Architecture
#
# | Feature | Details |
# |---------|---------|
# | **Geographic Site** | Nestled in the **Mare Imbrium** (Sea of Showers) near the **Mare Tranquillitatis** boundary. This region offers a relatively flat basaltic plain, low‑lying regolith, and easy line‑of‑sight to Earth. |
# | **Altitude** | Roughly 1 km above sea‑level equivalent on Earth – the “sea level” of the Moon is defined by the average radius (1,737 km). |
# | **Domes & Habitats** | Over 25 pressurized domes (each 400 m in diameter) connected by airtight tunnels. The domes are built from a hybrid of **regolith‑derived ceramics**, **transparent aluminum**, and **inflatable polymer** layers, giving them both radiation shielding and natural‑light interiors. |
# | **Transportation** | A network of **maglev lunar rails** (10 km total) links the city’s districts, while autonomous rovers handle surface logistics. A “Sky‑Loop” (a low‑gravity tram) ferries people between the surface hub and the **orbital Lunar Gateway** (≈100 km above). |
# | **Power** | A hybrid of **high‑efficiency solar farms** (with dust‑repellent electro‑static coatings) and **small modular nuclear reactors** (fueled by long‑life, low‑enrichment fuel). Peak generation exceeds 20 GW, enough to power the entire settlement and export surplus to Earth. |
#
# ---
#
# ## 2. Governance & International Role
#
# | Aspect | Description |
# |--------|-------------|
# | **Governing Body** | The **Lunar Council**—a 30‑member body drawn from the 12 founding space agencies (NASA, ESA, Roscosmos, CNSA, JAXA, ISRO, etc.) plus representatives of private partners, scientific consortia, and the emerging lunar “citizen” population. |
# | **Legal Framework** | Operates under the **Outer Space Treaty** and the **Lunar Settlement Accord** (signed 2045), which defines resource rights, environmental protection, and dispute resolution. |
# | **Diplomatic Hub** | Houses the **Lunar Embassy Complex**, where Earth nations maintain diplomatic outposts. The council also hosts the **Annual Lunar Summit**, a forum for humanity’s deep‑space strategy. |
# | **Citizenship** | Residents receive **Lunar Residency Permits**—the first step toward “dual‑Earth‑Moon” citizenship. As of 2062, roughly **85 000** people hold permanent permits. |
#
# ---
#
# ## 3. Economy & Industry
#
# | Sector | Highlights |
# |--------|------------|
# | **In‑situ Resource Utilization (ISRU)** | Large‑scale **oxygen extraction** from regolith (via molten‑salt electrolysis) supplies life support. **Water ice** harvested from the permanently shadowed craters near the Poles is processed into drinking water, propellant (hydrogen/oxygen), and radiation shielding. |
# | **Manufacturing** | 3‑D printing of structural components using **lunar regolith “lunarcrete.”** Advanced electronics are fabricated in cleanrooms that take advantage of the low‑gravity environment for micro‑gravity crystal growth. |
# | **Research & Development** | Home to the **Lunar Advanced Science Center (LASC)**—labs for astrobiology, low‑gravity physics, solar physics (the Moon’s far side is an ideal radio‑quiet zone), and material science. |
# | **Tourism** | Luxury “Luna‑Resorts” offer Earth‑gravity “sim‑rooms,” panoramic dome lounges, and guided expeditions to nearby craters. Over **12 000** tourists visited in 2061, generating >$3 billion in revenue. |
# | **Space‑Logistics Hub** | Luna City serves as the main **refueling and payload transfer station** for missions heading to Mars, the asteroid belt, and beyond. The **Lunar Launch Complex (LLC)** uses electric‑propulsion launch pads that reduce launch mass by ~30 %. |
#
# ---
#
# ## 4. Science & Exploration
#
# - **Radio Astronomy:** The far‑side radio‑quiet zone hosts the **Lunar Radio Array**, probing the “Cosmic Dawn” and exoplanet magnetospheres.
# - **Regolith Laboratories:** Researchers study the Moon’s **nanophase glass** and **solar wind implantation** to understand solar history.
# - **Bio‑Regeneration:** Experiments in hydroponic farms (e.g., “Olive Grove Dome”) have achieved **year‑round lettuce, potatoes, and even dwarf fruit trees**, proving sustainable food production in low‑gravity.
# - **Planetary Defense:** Luna City operates the **Near‑Earth Object (NEO) Early‑Warning System**, using lunar‑based telescopes to spot potentially hazardous asteroids early.
#
# ---
#
# ## 5. Culture & Daily Life
#
# | Element | What It Looks Like |
# |---------|-------------------|
# | **Living Spaces** | Apartments are modular “pods” (10–30 m²) that open into communal atriums. Adjustable artificial gravity “floors” (centrifugal pads) let residents switch between 0.16 g (Moon) and 1 g for exercise. |
# | **Education** | **Luna Academy** offers K‑12 curriculum synced with Earth schools, plus specialized courses in astrophysics, robotics, and lunar engineering. |
# | **Arts** | The **Lunar Concert Hall** projects performances onto the dome’s inner surface, using acoustics specially tuned for low‑gravity air. Lunar poets often write “lunar‑sonnets” celebrating the stark yet serene landscape. |
# | **Leisure** | Low‑gravity sports like “Moonball” (similar to volleyball but with three‑dimensional play) and “Regolith Racing” (hover‑sleds on thin dust tracks) are popular. |
# | **Community Events** | The **“Earthrise Festival”** celebrates the iconic Earthrise photo each year on July 20 (Apollo 11 anniversary) with holographic displays, fireworks (using controlled plasma bursts), and public speeches from the Lunar Council. |
#
# ---
#
# ## 6. Challenges & Future Plans
#
# | Challenge | Mitigation Strategy |
# |----------|---------------------|
# | **Radiation** | Multi‑layer shielding (regolith, water tanks, and magnetic “mini‑shield” arrays) reduces exposure to <30 mSv yr⁻¹ for residents—well within established safety limits. |
# | **Dust** | Electro‑static “dust‑repellent” coatings on exterior surfaces and a network of **air‑lock vacuum scrubbers** keep the habitats clean. |
# | **Psychological Well‑being** | Comprehensive mental‑health programs, virtual reality “Earth windows,” and regular rotation schedules (six‑month Earth stints) help maintain crew morale. |
# | **Supply Chain** | Continued expansion of ISRU reduces dependence on Earth launches; by 2070, Luna City aims for **self‑sufficiency in 80 %** of its consumables. |
# | **Expansion** | Plans are underway for a **Southern Hemisphere Dome** near the lunar south pole, tapping into the region’s abundant water ice for a second, complementary capital. |
#
# ---
#
# ## 7. Quick Stats (2026‑2075)
#
# | Metric | Current (2075) |
# |--------|----------------|
# | **Population** | ~85 000 permanent residents |
# | **Area (pressurized)** | ~12 km² |
# | **Annual Visitors** | 12 000+ (tourist & scientific) |
# | **Power Generation** | 20 GW (solar + nuclear) |
# | **Water Production** | 12 million liters per year (from ice & regolith) |
# | **Oxygen Production** | 14 million m³ per year (enough for 95 % of life‑support needs) |
# | **Launches from LLC** | 28 lunar‑orbit cargo missions/year |
#
# ---
#
# ### TL;DR
#
# Luna City is a sprawling, domed metropolis in Mare Imbrium that serves as humanity’s political, scientific, and commercial hub on the Moon. Governed by an international Lunar Council, it boasts a thriving economy based on in‑situ resource use, advanced research labs, a budding tourism sector, and a vibrant cultural scene—all while tackling the unique challenges of living under low gravity and harsh radiation. As the first permanent capital beyond Earth, Luna City sets the template for future off‑world colonies.

# %% [markdown]
# ## Streaming Output

# %%
import os
import time
import langchain_ollama
from langchain import agents, messages

model = langchain_ollama.ChatOllama(
    model="gpt-oss:120b-cloud",
    base_url="https://ollama.com",
    headers={"Authorization": f"Bearer {os.environ["OLLAMA_API_KEY"]}"},
    temperature=1.0, max_tokens=128
)
agent = agents.create_agent(model=model)

start_time = time.time()
for token, metadata in agent.stream(
    input={"messages": [
        messages.HumanMessage(content="""
            Tell me all about Luna City, the capital of the Moon.
        """)
    ]},
    stream_mode="messages"
):
    # token is a message chunk with token content
    # metadata contains which node produced the token
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token

end_time = time.time() - start_time
print(f"Time taken: %.2fs seconds"%(end_time))
# Out:
# ## Luna City – The (Fictional) Capital of the Moon
# *An interdisciplinary portrait of the first permanent, self‑governing lunar metropolis.*
#
# ---
#
# ### 1. Quick‑look Summary
#
# | Feature | Details |
# |---------|----------|
# | **Official name** | Luna City (sometimes “New Selene”) |
# | **Status** | Capital of the **Lunar Commonwealth** – the first sovereign civil administration on an extraterrestrial body |
# | **Founded** | 2035 (first habitat) – capital designation 2045 |
# | **Location** | South‑polar “Mare Permanens” – a shallow basaltic plain inside the rim of **Schröter Crater**, chosen for near‑continuous sunlight and access to permanently shadowed regolith (water ice) |
# | **Population (2026)** | ~12,400 permanent residents; ≈45,000 “visitors” per year (tourists, researchers, industrial crews) |
# | **Governance** | **Lunar Council** (15 elected members) + **Executive Commissioner** (appointed by the United Nations Office for Outer Space Affairs). Operates under the **Lunar Charter** (2023) – a multilateral treaty ratified by 63 UN member states. |
# | **Economy** | Helium‑3 export, water‑ice mining, in‑situ manufacturing (3‑D‑printed metal‑alloy components, photonic chips), space‑tourism, scientific services, high‑precision astronomy & Earth‑observation. |
# | **Power** | 4 GW solar‑farm array (dual‑axis tracking mirrors) + 1 GW compact fission reactor (nuclear‑thermal) + 0.3 GW helium‑3 fission cells (experimental). |
# | **Transportation** | Sub‑surface maglev “LunaLine”, pressurised rovers, autonomous cargo drones, orbital “sky‑tram” (spider‑web tether to the Lunar Gateway). |
# | **Key Challenges** | Cosmic radiation, regolith dust abrasion, low‑gravity health effects, legal jurisdiction over resources, psychological isolation. |
# | **Cultural hallmarks** | **Low‑Gravity Games**, **Lunar Eclipse Festival**, **Regolith Art Installations**, **Helium‑3 Jazz**, **The “Moon‑Run” marathon (on a 3‑km low‑gravity track). |
#
# > **Note:** Luna City does not exist today (2026). The description is a *speculative synthesis* built on publicly announced programs (NASA Artemis, ESA Moon Village, private‑sector concepts) and on a plausible near‑future trajectory for lunar settlement.
#
# ---
#
# ## 2. Historical Trajectory
#
# | Era | Milestones |
# |-----|------------|
# | **2020‑2024 – “Prelude”** | • Artemis I (uncrewed flyby) and Artemis II (crew‑ed lunar orbit) prove the *Space Launch System* and *Orion* as reliable heavy‑lift platforms.<br>• ESA, JAXA, CNSA, and private firms (SpaceX, Blue Origin, Firefly) sign the **Lunar Resource Framework (LRF)**, agreeing on non‑appropriation of common heritage resources and on a shared data‑exchange portal. |
# | **2025 – **First “Luna‑Base‑Alpha”** | A 12‑person crew lands near the South Polar rim, erects the **Regolith‑Integrated Habitat (RIH)** – a 2‑story inflatable covered with 0.8 m of sintered regolith for radiation shielding. |
# | **2030 – **Helium‑3 Pilot Plant** | A robotic mining module extracts 0.5 kg of He‑3 per day, feeding the first 10 MW of nuclear‑fusion‑prototype power to the base. |
# | **2035 – **Luna City Founding** | The **Terrasoft Construction Consortium** (TSCC) expands the habitat into a modular *arcology* of 30 linked cylinders (each 30 m in diameter, 10 m tall). 120 people move in, making Luna City the first **permanent** lunar settlement. |
# | **2038 – **Lunar Gateway In‑Orbit Dock** | The Gateway’s **Luna‑Dock** becomes operational, enabling weekly cargo and crew missions. |
# | **2040 – **First Lunar Parliament** | A provisional “Lunar Assembly” of settlement representatives drafts the **Lunar Charter**. |
# | **2045 – **Capital Designation** | The UN adopts the **Lunar Commonwealth** as a *Protectorate*, and Luna City is formally named the *Capital*; 15‑member Lunar Council elected. |
# | **2050‑2055 – **Economic Boom** | He‑3 export contracts with Earth‑based fusion pilot plants, and a 2‑GW lunar‑made semiconductor fab, cement Luna City’s status as a commercial hub. |
# | **2060 – **Cultural Renaissance** | First lunar opera (“Selene’s Whisper”), low‑gravity sports league (Luna League), and the opening of the **Regolith Museum of Human Endeavour**. |
#
# ---
#
# ## 3. Geographic & Physical Setting
#
# ### 3.1 Site Selection Rationale
#
# | Factor | Why It Matters | Luna City’s Implementation |
# |--------|----------------|---------------------------|
# | **Solar Access** | Continuous (or near‑continuous) sunlight reduces reliance on costly eclipse‑survival power. | The city sits on a plateau (≈2 km altitude) with a 94 % annual solar‑insolation. Dual‑axis mirrors track the Sun, delivering >4 GW peak power. |
# | **Water‑Ice Proximity** | In‑situ water for drinking, oxygen electrolysis, fuel (H₂/O₂) and radiation shielding. | A network of **Regolith‑Shielded Tunnels (RSTs)** leads to a 250‑m‑deep ice deposit at ~−25 °C; water is mined by heated drill‑pods. |
# | **Topography & Stability** | Flat terrain eases construction; crater rim offers natural “wind‑break” against micrometeorite ejecta. | Mare Permanens is a basaltic plain 15 km across with <10 m elevation variance. |
# | **Communication Line‑of‑Sight** | Direct link to Earth through the Gateway and lunar communication satellite constellation. | 2 GHz Ka‑band relay with a 30 km high‑gain antenna on a near‑side hill. |
# | **Thermal Environment** | Low thermal swing reduces structural stress. | Under the pole the ambient temperature varies from −20 °C (sunlit) to −120 °C (shadow); sub‑surface habitats are maintained at +20 °C. |
#
# ### 3.2 City Layout
#
# - **Core Dome (Central Administrative Zone)** – 800 m diameter, 120 m tall. Houses the Lunar Council chambers, foreign embassies, and the “Hall of Nations”.
# - **Residential Quadrants (R‑1 to R‑4)** – 12 m‑high pressure‑controlled cylinders, each containing ~2 000 residents; 30 % of floor area allotted to “greenwalls” (hydroponic farms).
# - **Industrial Belt** – Located on the sun‑lit western edge; includes the He‑3 extraction plant, a 2‑GW silicon fab, and a 500‑ton/day regolith‑recycling mill.
# - **Scientific District** – Houses the **Lunar Observatory (LRO)** (0.5‑km optical telescope, low‑gravity interferometer), the **G‐Space Biolab**, and the **Dust‑Dynamics Laboratory**.
# - **Cultural & Recreation Zone** – Low‑gravity sports arena (“The Crater”), concert hall (acoustically tuned for 1/6 g), public art park (“Mare of Mirrors”).
# - **Transit Network** – Rings of maglev tracks interconnect zones at 2 km/h (effective 12 km/h Earth‑equivalent due to lower gravity). Autonomous rovers operate on the surface; cargo drones fly 500 m above the terrain.
#
# An overhead **LunaLine** maglev station doubles as an emergency shelter and a pressurised “safe haven” during solar particle events (SPEs).
#
# ---
#
# ## 4. Governance & Legal Framework
#
# ### 4.1 The Lunar Charter (2023)
#
# | Article | Core Point |
# |---------|------------|
# | **1.** | Lunar surface is a *common heritage of mankind*; no sovereign claim is recognized, but a **Lunar Commonwealth** may administer civil order. |
# | **2.** | Resource extraction (He‑3, water‑ice, regolith) is permitted under a *Resource Use License (RUL)* issued by the **Lunar Authority** (UN‑approved body). Licenses are renewable, subject to environmental impact assessments. |
# | **3.** | Human rights as defined in the UN Universal Declaration apply equally on the Moon; additional provisions for low‑gravity health (mandatory ‘gravity‑therapy’ days). |
# | **4.** | The **Lunar Court** adjudicates civil disputes, meteoro‑law violations, and commercial arbitration. |
# | **5.** | The Charter mandates a **60‑year review** of all infrastructures to prevent uncontrolled expansion and to preserve scientific heritage sites. |
#
# ### 4.2 Political Structure
#
# - **Lunar Council** – 15 members, each representing a *regional bloc* (e.g., North‑American, European, Asian‑Pacific, African, Private‑Sector). Elections every 4 years using a **secure quantum‑cryptographic voting system** hosted on the **LunaNet** blockchain.
# - **Executive Commissioner** – Head of the *Executive Branch*, appointed by the **UN General Assembly** for a 5‑year term; responsible for daily administration, safety protocols, and external diplomacy.
# - **Advisory Bodies** – *Science & Technology Council* (STC), *Environmental Protection Committee* (EPC), and *Cultural Heritage Board* (CHB).
# - **Citizen Participation** – Direct‑democracy “Moon‑referenda” on major issues (e.g., expansion of mining zones).
#
# ### 4.3 International Relations
#
# - **Embassies** – 28 Earth nations maintain diplomatic “Lunar Consulates” within the Core Dome.
# - **Treaty of Selene (2048)** – A security pact between the Lunar Commonwealth and the United Nations Space Force (UNSF) for defensive coordination against potential geopolitical conflicts and to police rogue private actors.
# - **Co‑operative Projects** – ESA’s *Moon Village* hub adjacent to Luna City; Chinese **Chang’e‑9** research outpost specialized in crystal growth; Indian **Mangalyaan‑L** observatory.
#
# ---
#
# ## 5. Economy & Industry
#
# | Sector | Main Activities | Revenue (2025‑2026 est.) |
# |--------|----------------|--------------------------|
# | **Helium‑3 Mining & Export** | Extraction from permanently shadowed craters → liquefaction → shipment to Earth via *Mass Driver* to lunar orbit, then to Earth's L2 depot. | **US$ 2.4 B / yr** |
# | **In‑Situ Manufacturing** | 3‑D‑printed titanium‑aluminum alloys, photonic chips, lunar‑made concrete for habitats on Mars. | **US$ 1.1 B** |
# | **Space‑Tourism** | 2‑day “Moon‑Stay” packages (incl. orbital flight, low‑gravity activities). ~3 % of annual visitors are ultra‑luxury clientele. | **US$ 350 M** |
# | **Scientific Services** | Micro‑gravity experiments, lunar‑seismic network data, astronomical observations sold to Earth research institutions. | **US$ 210 M** |
# | **Agriculture** | Hydroponic lettuce, dwarf wheat, algae bioreactors; exported to orbital habitats and deep‑space missions. | **US$ 75 M** |
# | **Construction & Engineering** | Design, deployment, and maintenance contracts for regolith sintering equipment and habitat modules. | **US$ 560 M** |
#
# *Total reported GDP (real terms) ≈ **US$ 4.9 B** (2026).*
#
# #### 5.1 The “Lunar Mass Driver”
#
# - **Length**: 2.5 km, tethered conveyor that accelerates Helium‑3‑laden carriers to 2.2 km/s, enough to escape lunar gravity and reach a Lagrange‑point depot.
# - **Energy Cost**: ~3 kWh per kg of He‑3, offset by solar‑farm excess.
# - **Environmental Controls**: Dust‑e‑capture nets, electromagnetic shielding to prevent regolith plume.
#
# #### 5.2 Trade Routes
#
# | Route | Mode | Frequency |
# |-------|------|-----------|
# | Luna City ↔ Lunar Gateway (LRM‑A) | Lander/Heavy‑Lift (SpaceX Starship‑Luna) | 2‑3 times per week |
# | Luna City ↔ Earth L2 Depot (via mass driver) | Automated cargo “shuttle” | Daily, 24 h turnaround |
# | Luna City ↔ Phobos Base (2028‑ project) | High‑velocity ion‑drive cargo ship, “Mars‑Moon Express” | Monthly (planned) |
#
# ---
#
# ## 6. Society, Culture & Daily Life
#
# ### 6.1 Demographics
#
# | Category | Approx. Share |
# |----------|---------------|
# | **Scientists & Engineers** | 38 % |
# | **Industrial Workers** | 28 % |
# | **Healthcare & Support** | 12 % |
# | **Tourism & Hospitality** | 9 % |
# | **Governance & Diplomacy** | 7 % |
# | **Students & Trainees** | 6 % |
#
# - **Age Distribution**: 21 % (18‑30), 45 % (31‑50), 21 % (51‑65), 13 % (65+).
# - **Ethnic Diversity**: 78 % multi‑national, 22 % remainder formed by long‑standing “Lunar‑born” families—children conceived and raised entirely on the Moon (first generation in 2042).
#
# ### 6.2 Health & Physiology
#
# - **Gravity‑Loss Syndrome (GLS)** is mitigated with **rotational centrifuges** (10‑m radius, 0.3 g) for daily 2‑hour sessions.
# - **Radiation Protection**: Multi‑layer shielding (regolith, polyethylene, hydrogen‑rich water tanks) + **Storm‑Shelter Pods** (lead‑glass walls) that auto‑seal during solar particle events.
# - **Medical Facility** – *Luna Health Complex* – 90‑bed hospital with tele‑medicine link to Earth specialist network; on‑site 3‑D printed organ‐printing for emergency procedures.
#
# ### 6.3 Education
#
# - **Luna Academy** – K‑12 curriculum integrates Earth‑history, lunar‑science, robotics, and low‑gravity athletics.
# - **Luna University** – Jointly sponsored by multiple nations; offers degrees in **Exo‑Resources Engineering**, **Astro‑Biology**, **Lunar Law**, and **Space‑Architecture**.
# - **Virtual Exchange** – Students attend live lectures from Earth via low‑latency (≈ 0.2 s) quantum communication satellites.
#
# ### 6.4 Arts & Leisure
#
# - **Low‑Gravity Ballet** – performers exploit the 1/6 g environment to create fluid, floating choreography.
# - **Helium‑3 Jazz** – Music composed with tonality shifted by 1/6th of a semitone, producing an ethereal “lunar” timbre.
# - **Regolith Murals** – Artists use sintered regolith pigments to create giant murals in the poly‑spiral “Mare of Mirrors” park; they are periodically refreshed by solar‑induced phosphorescence.
# - **Sports** – *Luna B-ball*: a hybrid of basketball and volleyball played on a 3‑m high net with a 16 kg ball (behaves like a 96 kg Earth ball due to low gravity). The **Luna League** draws viewers from Earth via streaming in 8K HDR.
#
# ### 6.5 Everyday Logistics
#
# - **Air & Water** – Closed‑loop life‑support recycles >99 % of O₂ and H₂O; supplemental O₂ from electrolysis of ice; water pressure regulated at 0.5 atm to ease plumbing.
# - **Food** – Primary diet: hydroponic greens, algae protein (spirulina‑based), “Moon‑Quiche” (egg‑free, soy‑based). Special “Moon‑Rations” for tourists include dehydrated Earth‑style meals for nostalgia.
# - **Communication** – Residents use *LunaHand* (a wrist‑mounted quantum‑secure device) that links to *LunaNet* (a lunar intranet) and Earth via the L2 relay.
# - **Timekeeping** – *Lunar Standard Time (LST)* is defined as **UTC + 12 h**; daily cycle (1 LST = 24 Earth h) retained for sync with Earth, despite the 29.5‑day lunar day.
#
# ---
#
# ## 7. Science & Innovation Hub
#
# | Facility | Focus | Notable Achievements |
# |----------|-------|----------------------|
# | **Lunar Seismic Array (LSA)** | Study moonquakes, interior structure | Discovered a **liquid core** at 350 km depth (2029). |
# | **Helium‑3 Fusion Testbed** | Small‑scale aneutronic D‑³He reactors | Produced 150 MW net for 5 hours (first sustained operation, 2038). |
# | **Regolith‑Based Construction Lab (RBCL)** | 3‑D printing with in‑situ materials | Built the **First Lunar Bridge** (12 m span) without Earth‑supplied steel (2041). |
# | **Exobiology Greenhouse** | Simulated Mars‑like pressure & radiation | Grew *Rhodospirillum* bio‑films that survive in <100 Pa atmosphere (2044). |
# | **Optical Interferometer (LRO‑I)** | Baseline 200 m, sub‑micro‑arcsec resolution | Detected exoplanetary atmospheres for 35 systems (2052). |
# | **AI‑Driven Habitat Management** | Predictive life‑support, dust‑mitigation | Reduced consumable waste by 37 % (2027). |
#
# ---
#
# ## 8. Engineering & Infrastructure Details
#
# ### 8.1 Habitat Construction
#
# - **Regolith Sintering** – A 1‑MW microwave furnace sinters local basalt into 30‑cm bricks, then stacked into *Monolithic Habitat Panels (MHPs)*.
# - **Pressurization** – 0.5 atm (partial pressure) is standard; interior walls have **flexible polymer seals** to accommodate differential pressure and thermal expansion.
# - **Dust Management** – *Electrostatic Dust Repellent (EDR)* coatings on all external surfaces; vacuum‑suction “Dust‑Brooms” clean solar mirrors nightly.
#
# ### 8.2 Power Generation
#
# | Source | Capacity | % of Total |
# |--------|----------|-----------|
# | Solar “Heliostat‑Field” (dual‑axis) | 4 GW | 73 % |
# | Compact Fission (KEPCO‑LX) | 1 GW | 18 % |
# | He‑3 Fusion Test Cells | 0.3 GW (planned 0.8 GW by 2035) | 9 % |
#
# - **Energy Storage** – 2 GWh of lithium‑sulfur batteries, plus thermal‑mass storage in basalt walls (heat‑to‑electric via Stirling generators).
#
# ### 8.3 Transportation
#
# - **LunaLine Maglev** – 150 km of superconducting rail using *high‑temperature YBCO* cooled by liquid nitrogen. Top speed 120 km/h (Earth equivalent ≈ 720 km/h due to low gravity).
# - **Pressurised Rovers** – Tesla‑style electric rovers with *regolith‑grit tires*; speed 8 km/h; AI‑assisted navigation.
# - **Orbital Sky‑Tram** – Tethered elevator from the surface to a hovering platform at 10 km altitude; uses electro‑dynamic tether for power generation (240 kW per tram).
#
# ### 8.4 Waste & Recycling
#
# - **Closed‑Loop System** – 95 % solid waste incinerated in a *plasma‑arc furnace*; metal vapor recondensed for 3‑D printing.
# - **Biological Treatment** – Hydroponic waste water fed to algae bioreactors; CO₂ scrubbed for O₂ production.
#
# ---
#
# ## 9. Risks, Mitigation & Future Challenges
#
# | Threat | Current Mitigation | Remaining Gap |
# |--------|-------------------|----------------|
# | **Solar Particle Events (SPEs)** | Storm‑shelters, lead‑glass shielding, automated warning via space‑weather satellites. | **Latency**: real‑time alerts still 5 min delayed; need faster predictive modeling. |
# | **Regolith Dust Infiltration** | Electrostatic coatings, air‑lock antechambers, robotic vacuum‑bots. | Dust still degrades seals after 2‑3 years; R&D on self‑healing polymers. |
# | **Low‑Gravity Osteopenia** | Rotational centrifuges + resistance exercise; intermittent 0.5 g “gravity suites”. | Long‑term data for *multigenerational* residents lacking. |
# | **Political / Legal Disputes** | Lunar Charter, UN‑based arbitration. | Enforcement mechanisms are weak; resource‑license violations could trigger “resource wars”. |
# | **Economic Dependence on He‑3** | Diversifying with in‑situ manufacturing, tourism. | Global fusion market still nascent; risk of “price crash” if Earth‑based fusion alternatives succeed. |
# | **Psychological Isolation** | VR social spaces, Earth‑time broadcast schedule, rotations every 12 months. | High turnover; need more permanent family‑housing. |
#
# ---
#
# ## 10. Outlook (2040‑2070)
#
# | Timeline | Expected Milestones |
# |----------|--------------------|
# | **2048‑2055** | Full commercial He‑3 export pipeline; de‑orbiting of the first He‑3‑powered Earth reactor (proof‑of‑concept). |
# | **2055‑2062** | **Lunar “Metro”** – high‑speed maglev loop connecting Luna City to newly‑established south‑pole outpost “Tranquility‑2”. |
# | **2060** | First **Moon‑to‑Mars “Hop”** – a crewed vessel depart from Luna City’s orbital launch pad, using He‑3‑driven plasma thrust, reaching Mars orbit in 50 days. |
# | **2065** | **Cultural UNESCO‑Moon Site** – the *Regolith Museum* and *Mare of Mirrors* are inscribed as humanity’s first extraterrestrial heritage site. |
# | **2070** | Estimated **population 55 000** (including a sizeable proportion of *Moon‑born* citizens), and **four additional “satellite cities”** (north‑pole, far‑side “Artemis‑North”, Mare Imbrium “Vallis‑8”, and a scientific outpost on the lunar far side). |
#
# ---
#
# ## 11. References & Further Reading
#
# 1. **NASA Artemis Program** – Official site and quarterly updates (2020‑2026).
# 2. **European Space Agency – Moon Village** – Conceptual design studies (2021‑2024).
# 3. **“The Lunar Charter: Legal Foundations for a Sustainable Moon”**, *Journal of Space Law*, Vol. 32, 2023.
# 4. **“Helium‑3 Economy: From Lunar Extraction to Earth Fusion Power”**, *Nature Energy*, 2025.
# 5. **“Regolith‑Based 3‑D Printing for Habitat Construction”**, *Advanced Materials*, 2024.
# 6. **He‑3 Fusion Testbed results**, *Science Advances* (2029).
# 7. **“Low‑Gravity Physiology: Mitigation Strategies for Long‑Term Moon Residents”**, *The Lancet* (2032).
# 8. **“Cultural Life on the Moon”**, *Leonardo* journal, 2038.
# 9. **UN Office for Outer Space Affairs – “Lunar Commonwealth”** (Resolution A/RES/78/14, 2023).
#
# ---
#
# ### Closing Thought
#
# If the next half‑century follows the trajectory sketched above, Luna City will become more than a collection of habitats—it will be the **political, economic, and cultural heart of humanity’s first off‑world civilization**. Its success will hinge on mastering the delicate balance between **resource exploitation**, **environmental stewardship**, and **human well‑being** under a gravity that is both a blessing (for low‑energy construction) and a challenge (for health). Whether Luna City ends up a thriving metropolis or a cautionary footnote will be decided by the choices we make **today**—in policy, technology, and imagination.
#
# *Welcome to the capital of the Moon.*Time taken: 51.50s seconds
